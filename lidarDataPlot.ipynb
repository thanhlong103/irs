# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV file
data_top = pd.read_csv('./data/top.csv') 
data_left = pd.read_csv('./data/left.csv')
data_right = pd.read_csv('./data/right.csv')

left = (0.32,-1.51)
top = (0.96, -1,00)

data_left.head()
# Out:
#           x         y
# 0 -0.971102 -0.016951
# 1 -0.966919 -0.025308
# 2 -0.967911 -0.033777
# 3 -0.966081 -0.042145
# 4 -0.962182 -0.050379

# %%
# Scatter plot
plt.scatter(data_top.iloc[:, 0] , data_top.iloc[:, 1] , color='red', marker='o')
plt.scatter(data_left.iloc[:, 0] , data_left.iloc[:, 1] , color='blue', marker='o')
plt.scatter(data_right.iloc[:, 0] , data_right.iloc[:, 1] , color='green', marker='o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of X vs Y')
plt.grid(True)
plt.show()
